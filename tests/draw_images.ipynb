# %%
# %matplotlib inline
#%load_ext autoreload
# %reload_ext autoreload
from matplotlib.pyplot import imshow

# PIL library to process images.
import pylab
from PIL import Image, ImageFont, ImageDraw

# %%
from lib.imagegen.shape import Square, Circle, Triangle
from lib.imagegen.draw import ImageCreate
from lib.imagegen.draw import gen_one_shape_image

# %%
image_size = (600, 600)
num_shapes = 1
b_color = (255, 255, 255)
max_shape_size = 30
base_file_name = "datasets/images/size_1/"
color_list = ['black', 'blue', 'red', 'green', 'yellow', 'purple', 'violet', 'orange']

# Create the Image.
i = ImageCreate(image_size, num_shapes, background_color=b_color)
gen_one_shape_image(image_size, max_shape_size, b_color, base_file_name, color_list)
# Out:
# (15, 15)
# (15, 45)
# (15, 75)
# (15, 105)
# (15, 135)
# (15, 165)
# (15, 195)
# (15, 225)
# (15, 255)
# (15, 285)
# (15, 315)
# (15, 345)
# (15, 375)
# (15, 405)
# (15, 435)
# (15, 465)
# (15, 495)
# (15, 525)
# (15, 555)
# (45, 15)
# (45, 45)
# (45, 75)
# (45, 105)
# (45, 135)
# (45, 165)
# (45, 195)
# (45, 225)
# (45, 255)
# (45, 285)
# (45, 315)
# (45, 345)
# (45, 375)
# (45, 405)
# (45, 435)
# (45, 465)
# (45, 495)
# (45, 525)
# (45, 555)
# (75, 15)
# (75, 45)
# (75, 75)
# (75, 105)
# (75, 135)
# (75, 165)
# (75, 195)
# (75, 225)
# (75, 255)
# (75, 285)
# (75, 315)
# (75, 345)
# (75, 375)
# (75, 405)
# (75, 435)
# (75, 465)
# (75, 495)
# (75, 525)
# (75, 555)
# (105, 15)
# (105, 45)
# (105, 75)
# (105, 105)
# (105, 135)
# (105, 165)
# (105, 195)
# (105, 225)
# (105, 255)
# (105, 285)
# (105, 315)
# (105, 345)
# (105, 375)
# (105, 405)
# (105, 435)
# (105, 465)
# (105, 495)
# (105, 525)
# (105, 555)
# (135, 15)
# (135, 45)
# (135, 75)
# (135, 105)
# (135, 135)
# (135, 165)
# ...

# %%
a = Square((100, 200), 100, fill_color='green', outline_color='green')

# %%
i.create_new_image()
i.dr_add(a)

# %%
b = Circle((150, 150), 100, fill_color='blue', outline_color='blue')

# %%
i.dr_add(b)

# %%
c = Triangle((150,0), 100, fill_color='orange', outline_color='orange')

# %%
i.dr_add(c)

# %%
#pylab.axis('off'); pylab.imshow(i.get_image())
print(i.get_image())

# %%
pylab.axis('off'); pylab.imshow(i.get_image())
